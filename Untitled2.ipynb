# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Make a reference to the books.csv file path
csv_path = "Resources/Parkingtickets_Dec2016.csv"

# Import the books.csv file as a DataFrame
tickets_df = pd.read_csv(csv_path, encoding="utf-8")
tickets_df.head()
# Out:
#   Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0  GYG8911                 NY        PAS  12/18/2016              24
# 1    8P82H                 NY        OMT  12/21/2016              14
# 2  GML6346                 NY        PAS  12/19/2016              21
# 3  12203MG                 NY        COM   12/1/2016              46
# 4  HEG7444                 NY        PAS   12/1/2016              36
#
#   Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 0              SUBN         JEEP          1204P                Q
# 1              TAXI        NISSA          1015A               NY
# 2               SDN        HONDA          1212P                K
# 3               VAN        FRUEH          1137A               NY
# 4              4DSD          BMW          1027A               BK
#
#   From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 0                  NaN                NaN            BK          2015
# 1                  ALL                ALL         YELLO          2014
# 2                1130A              0100A          GREY          2013
# 3                  ALL                ALL         BROWN          2015
# 4                  NaN                NaN            BK          2016
#
#   Meter Number Violation Post Code           Violation Description
# 0          NaN                15 4    24-No Parking (exc auth veh)
# 1            -                 NaN                             NaN
# 2            -                 NaN                             NaN
# 3            -                 NaN                             NaN
# 4          NaN                 NaN  PHTO SCHOOL ZN SPEED VIOLATION

# %%
#groupby plate type 
plate_gb = tickets_df.groupby("Plate Type")["Violation Code"].nunique()
plate_gb.head()
# Out:
# Plate Type
# 999    16
# AMB     1
# APP     4
# AYG     1
# BOB     1
# Name: Violation Code, dtype: int64

# %% [markdown]
# # Bar Chart

# %%
plate_gb.plot(kind="bar")

#title
plt.title("Plate Type Vs Number of Unique violation codes")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0.5, 1.0, 'Plate Type Vs Number of Unique violation codes')

# %%
tickets_df["Violation Code"] = tickets_df["Violation Code"].apply(str)
tickets_df.dtypes
# Out:
# Plate ID                 object
# Registration State       object
# Plate Type               object
# Issue Date               object
# Violation Code           object
# Vehicle Body Type        object
# Vehicle Make             object
# Violation Time           object
# Violation County         object
# From Hours In Effect     object
# To Hours In Effect       object
# Vehicle Color            object
# Vehicle Year              int64
# Meter Number             object
# Violation Post Code      object
# Violation Description    object
# dtype: object

# %%
#get all the data for PAS
pass_data = tickets_df.loc[tickets_df["Plate Type"] == "PAS"]
pass_data.head()
# Out:
#   Plate ID Registration State Plate Type  Issue Date Violation Code  \
# 0  GYG8911                 NY        PAS  12/18/2016             24
# 2  GML6346                 NY        PAS  12/19/2016             21
# 4  HEG7444                 NY        PAS   12/1/2016             36
# 7  HLF3741                 NY        PAS  12/21/2016             38
# 8  HJF2092                 NY        PAS   12/3/2016             38
#
#   Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 0              SUBN         JEEP          1204P                Q
# 2               SDN        HONDA          1212P                K
# 4              4DSD          BMW          1027A               BK
# 7              4DSD        INFIN          0943P                K
# 8              SUBN          BMW          0204P                K
#
#   From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 0                  NaN                NaN            BK          2015
# 2                1130A              0100A          GREY          2013
# 4                  NaN                NaN            BK          2016
# 7                0800A              1000P            GY          2016
# 8                0900A              0700P            BL          2016
#
#   Meter Number Violation Post Code           Violation Description
# 0          NaN                15 4    24-No Parking (exc auth veh)
# 2            -                 NaN                             NaN
# 4          NaN                 NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 7          NaN                U 31  38-Failure to Display Muni Rec
# 8          NaN                19 3  38-Failure to Display Muni Rec

# %%
pas_violation_codes_df = pd.DataFrame(pass_data['Violation Code'].value_counts()).nlargest(10, columns = ['Violation Code'])
pas_violation_codes_df
# Out:
#     Violation Code
# 36            6349
# 21            3301
# 38            2166
# 7             1431
# 71            1245
# 37            1220
# 20            1039
# 14             911
# 40             888
# 70             691

# %%
# counts_five = top_violation_codes_df["Violation Code"].value_counts().rename_axis("Violation codes for PAS plate type").reset_index(name="Number of violations")
# counts_five

# %%
counts = pass_data["Violation Code"].value_counts().rename_axis("Violation codes for PAS plate type").reset_index(name="Number of violations")
counts = counts.set_index("Violation codes for PAS plate type")
counts.head()
# Out:
#                                     Number of violations
# Violation codes for PAS plate type
# 36                                                  6349
# 21                                                  3301
# 38                                                  2166
# 7                                                   1431
# 71                                                  1245

# %%
counts.plot(kind="bar", figsize=(8,3))
plt.title("Violation codes for PAS Plate Type")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
com_data = tickets_df.loc[tickets_df["Plate Type"] == "COM"]
com_data.head()
# Out:
#    Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 3   12203MG                 NY        COM   12/1/2016              46
# 5   34719MG                 NY        COM   12/8/2016              50
# 14  91028MJ                 NY        COM  12/13/2016              14
# 15  59654MG                 NY        COM  12/21/2016              36
# 16  68218MG                 NY        COM  12/13/2016              47
#
#    Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 3                VAN        FRUEH          1137A               NY
# 5               DELV        INTER          0742A               NY
# 14              DELV        FRUEH          1012A               NY
# 15               VAN         FORD          0921A               BK
# 16               VAN        NS/OT          1039A               NY
#
#    From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 3                   ALL                ALL         BROWN          2015
# 5                   NaN                NaN            BL          2015
# 14                0700A              0700P         WHITE          2017
# 15                  NaN                NaN            BK          2015
# 16                0700A              0700P         BLACK          2015
#
#    Meter Number Violation Post Code           Violation Description
# 3             -                 NaN                             NaN
# 5           NaN                J 99                    50-Crosswalk
# 14          NaN                22 7                  14-No Standing
# 15          NaN                 NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 16          NaN                14 6           47-Double PKG-Midtown

# %%
com_violation_codes_df = pd.DataFrame(com_data['Violation Code'].value_counts()).nlargest(10, columns = ['Violation Code'])
com_violation_codes_df
# Out:
#     Violation Code
# 14             605
# 46             480
# 38             439
# 37             282
# 36             230
# 69             217
# 21             216
# 16             196
# 19             189
# 47             136

# %%
com_counts = com_data["Violation Code"].value_counts().rename_axis("Violation codes for COM plate type").reset_index(name="Number of violations")
com_counts = com_counts.set_index("Violation codes for COM plate type")
counts.head()
# Out:
#                                     Number of violations
# Violation codes for PAS plate type
# 36                                                  6349
# 21                                                  3301
# 38                                                  2166
# 7                                                   1431
# 71                                                  1245

# %%
com_counts.plot(kind="bar", figsize=(8,3))
plt.title("Violation codes for COM Plate type")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
omt_data = tickets_df.loc[tickets_df["Plate Type"] == "OMT"]
omt_data.head()
# Out:
#     Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 1      8P82H                 NY        OMT  12/21/2016              14
# 35  T668755C                 NY        OMT  12/14/2016               7
# 45  T700191C                 NY        OMT  12/16/2016              89
# 46  T711289C                 NY        OMT  12/10/2016              40
# 47  T685816C                 NY        OMT  12/27/2016              21
#
#    Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 1               TAXI        NISSA          1015A               NY
# 35              4DSD        HONDA          1156P               MN
# 45              SUBN          GMC          1045A                K
# 46              SUBN        TOYOT          0221A                Q
# 47              4DSD        TOYOT          1139A                Q
#
#    From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 1                   ALL                ALL         YELLO          2014
# 35                  NaN                NaN            BK          2014
# 45                  ALL                ALL         BLACK          2015
# 46                  NaN                NaN            BK          2016
# 47                1130A              0100P            BK          2015
#
#    Meter Number Violation Post Code         Violation Description
# 1             -                 NaN                           NaN
# 35          NaN                 NaN  FAILURE TO STOP AT RED LIGHT
# 45            -                 NaN                           NaN
# 46          NaN                C 42               40-Fire Hydrant
# 47          NaN                30 4  21-No Parking (street clean)

# %%
omt_violation_codes_df = pd.DataFrame(omt_data['Violation Code'].value_counts()).nlargest(10, columns = ['Violation Code'])
omt_violation_codes_df
# Out:
#     Violation Code
# 36             572
# 21             360
# 7              284
# 14             164
# 38             149
# 9              147
# 5              132
# 20             126
# 40             118
# 46             113

# %%
omt_counts = omt_data["Violation Code"].value_counts().rename_axis("Violation codes for OMT plate type").reset_index(name="Number of violations")
omt_counts = omt_counts.set_index("Violation codes for OMT plate type")
omt_counts.head()
# Out:
#                                     Number of violations
# Violation codes for OMT plate type
# 36                                                   572
# 21                                                   360
# 7                                                    284
# 14                                                   164
# 38                                                   149

# %%
omt_counts.plot(kind="bar", figsize=(8,3))
plt.title("Violation codes for OMT plate type")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
oms_data = tickets_df.loc[tickets_df["Plate Type"] == "OMS"]
oms_data.head()
# Out:
#     Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 90   GXP3410                 NY        OMS  12/13/2016              38
# 124  HFX1696                 NY        OMS   12/7/2016              38
# 171  HKE6426                 NY        OMS  12/16/2016              36
# 232  GTV4799                 NY        OMS   12/8/2016              48
# 362  HJD5994                 NY        OMS  12/23/2016              36
#
#     Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 90               SUBN        DODGE          0210P                Q
# 124              SUBN        DODGE          0926A                K
# 171              SUBN        CHRYS          1045A               QN
# 232              SUBN          BMW          0330P                K
# 362              4DSD        CHEVR          1107A               BK
#
#     From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 90                 0800A              0700P            GY          2016
# 124                0900A              0700P            BK          2016
# 171                  NaN                NaN            BK          2017
# 232                  NaN                NaN            BL          2017
# 362                  NaN                NaN            WH          2016
#
#     Meter Number Violation Post Code           Violation Description
# 90           NaN                20 4  38-Failure to Display Muni Rec
# 124          NaN                05 3  38-Failure to Display Muni Rec
# 171          NaN                 NaN  PHTO SCHOOL ZN SPEED VIOLATION
# 232          NaN                09 3                    48-Bike Lane
# 362          NaN                 NaN  PHTO SCHOOL ZN SPEED VIOLATION

# %%
oms_violation_codes_df = pd.DataFrame(oms_data['Violation Code'].value_counts()).nlargest(10, columns = ['Violation Code'])
oms_violation_codes_df
# Out:
#     Violation Code
# 36             171
# 21             115
# 38              67
# 7               48
# 14              37
# 40              35
# 37              35
# 20              34
# 71              21
# 46              19

# %%
oms_counts = oms_data["Violation Code"].value_counts().rename_axis("Violation codes for OMS plate type").reset_index(name="Number of violations")
oms_counts = oms_counts.set_index("Violation codes for OMS plate type")
oms_counts.head()
# Out:
#                                     Number of violations
# Violation codes for OMS plate type
# 36                                                   171
# 21                                                   115
# 38                                                    67
# 7                                                     48
# 14                                                    37

# %%
oms_counts.plot(kind= "bar", figsize=(8,3))
plt.title("Violation codes for OMS plate type")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
srf_data = tickets_df.loc[tickets_df["Plate Type"] == "SRF"]
srf_data.head()
# Out:
#      Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 6       100VM                 NY        SRF   12/7/2016              20
# 42   EZRUNER1                 NY        SRF  12/29/2016              21
# 82   JAZZFUSE                 NY        SRF   12/9/2016              21
# 197  R1CECAKE                 NY        SRF   12/6/2016              21
# 206   BHNYLAW                 NY        SRF  12/24/2016              38
#
#     Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 6                SUBN         JEEP          0440P               NY
# 42               PICK        NS/OT          1107A               NY
# 82               SUBN        MAZDA          0946A               BX
# 197              SUBN         JEEP          0937A                K
# 206              4DSD        LEXUS          1035A                K
#
#     From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 6                  0800A              0600P         WHITE          2013
# 42                 1100A              1230A         BLACK          2014
# 82                 0930A              1100A            GY          2016
# 197                0930A              1100A            WH          2013
# 206                0900A              0700P          GREY          2015
#
#     Meter Number Violation Post Code           Violation Description
# 6            NaN                 01B        20A-No Parking (Non-COM)
# 42           NaN                47 7    21-No Parking (street clean)
# 82           NaN                B 21    21-No Parking (street clean)
# 197            -                 NaN                             NaN
# 206          NaN                41 3  38-Failure to Display Muni Rec

# %%
srf_violation_codes_df = pd.DataFrame(srf_data['Violation Code'].value_counts()).nlargest(10, columns = ['Violation Code'])
srf_violation_codes_df
# Out:
#     Violation Code
# 36             107
# 38              40
# 21              38
# 7               23
# 37              20
# 20              18
# 40              16
# 71              16
# 70              15
# 14              11

# %%
srf_counts = srf_data["Violation Code"].value_counts().rename_axis("Violation codes for SRF plate type").reset_index(name="Number of violations")
srf_counts = srf_counts.set_index("Violation codes for SRF plate type")
oms_counts.head()
# Out:
#                                     Number of violations
# Violation codes for OMS plate type
# 36                                                   171
# 21                                                   115
# 38                                                    67
# 7                                                     48
# 14                                                    37

# %%
srf_counts.plot(kind="bar", figsize=(8,3))
plt.title("Violation codes for SRF plate type")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
