# %%
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Make a reference to the books.csv file path
csv_path = "Resources/Parkingtickets_Dec2016.csv"

# Import the books.csv file as a DataFrame
tickets_df = pd.read_csv(csv_path, encoding="utf-8")
tickets_df.head()
# Out:
#   Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0  GYG8911                 NY        PAS  12/18/2016              24
# 1    8P82H                 NY        OMT  12/21/2016              14
# 2  GML6346                 NY        PAS  12/19/2016              21
# 3  12203MG                 NY        COM   12/1/2016              46
# 4  HEG7444                 NY        PAS   12/1/2016              36
#
#   Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 0              SUBN         JEEP          1204P                Q
# 1              TAXI        NISSA          1015A               NY
# 2               SDN        HONDA          1212P                K
# 3               VAN        FRUEH          1137A               NY
# 4              4DSD          BMW          1027A               BK
#
#   From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 0                  NaN                NaN            BK          2015
# ...

# %%
Plate_count = tickets_df['Plate Type'].value_counts()
Plate_count
# Out:
# PAS    22298
# COM     4163
# OMT     2651
# OMS      690
# SRF      346
# IRP      189
# ORG       74
# 999       60
# TRC       60
# MED       59
# OML       52
# SPO       42
# OMR       38
# PSD       28
# TOW       27
# RGL       26
# SCL       23
# VAS       22
# MOT       12
# SRN       12
# APP        9
# ITP        6
# TRL        4
# CMH        3
# CHC        3
# AYG        2
# TRA        2
# SEM        2
# ORC        2
# PHS        1
# STA        1
# NLM        1
# DLR        1
# AMB        1
# BOB        1
# HIR        1
# LMB        1
# Name: Plate Type, dtype: int64

# %%
plate_type = tickets_df.groupby(["Plate Type"])
plate_type

# %%
plate_type_ct = plate_type["Plate Type"].nunique()
# plate_type_ct
plate_type_ct.count()
# Out:
# 37

# %%
# mini2016 = tickets_df.sample(frac = 0.25, replace = False)

# %%
# mini2016.shape
# tickets_df.shape

# %%
# Plate_count = mini2016['Plate Type'].value_counts()
# Plate_count

# %%
top_plate_types_df = pd.DataFrame(tickets_df['Plate Type'].value_counts()/len(tickets_df)).nlargest(5, columns = ['Plate Type'])
top_plate_types_df
# Out:
#      Plate Type
# PAS    0.721315
# COM    0.134668
# OMT    0.085757
# OMS    0.022321
# SRF    0.011193

# %%
explode = 0.05,0,0,0,0
plate_pie = top_plate_types_df.plot(kind="pie", subplots=True, explode=explode, autopct="%1.1f%%", startangle=90)
plt.show()
# plt.axis("equal")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# pass_plate = top_plate_types_df.loc(top_plate_types_df["Plate Type"] == "PAS")
# pass_plate

# %%
# top_plate_types_df.filter(items =["Plate Type"])

# %%
pass_plate = top_plate_types_df.filter(like="PAS", axis=0)
pass_plate
# Out:
#      Plate Type
# PAS    0.721315

# %%
codes_gb = tickets_df.groupby(["Violation Code"])
codes_gb

# %%
count_codes = codes_gb["Violation Code"].count()
count_codes
# count_codes.count()
# Out:
# Violation Code
# 4        3
# 5      567
# 7     1884
# 8        4
# 9      330
#       ...
# 85      24
# 89       4
# 95       1
# 98     143
# 99       5
# Name: Violation Code, Length: 67, dtype: int64

# %%
#considering a sample of data:
# mini2016 = tickets_df.sample(frac = 0.25, replace = False)

# %%
#Calculate the value counts of individual violation codes:
# count = mini2016["Violation Code"].value_counts()
# count
# count.head()

# %%
#converting to string:
tickets_df["Violation Code"] = tickets_df["Violation Code"].apply(str)
tickets_df.dtypes
# Out:
# Plate ID                 object
# Registration State       object
# Plate Type               object
# Issue Date               object
# Violation Code           object
# Vehicle Body Type        object
# Vehicle Make             object
# Violation Time           object
# Violation County         object
# From Hours In Effect     object
# To Hours In Effect       object
# Vehicle Color            object
# Vehicle Year              int64
# Meter Number             object
# Violation Post Code      object
# Violation Description    object
# dtype: object

# %%
# count_str = mini2016["Violation Code"].value_counts()
# count_str.head()

# %%
top_counts = pd.DataFrame(tickets_df['Violation Code'].value_counts()).nlargest(10, columns = ['Violation Code'])
top_counts
# Out:
#     Violation Code
# 36            7621
# 21            4069
# 38            2909
# 7             1884
# 14            1822
# 37            1653
# 71            1474
# 20            1345
# 46            1281
# 40            1210

# %%
#Plot a bar graph between violation codes and their corresponding counts:
counts_chart = top_counts.plot(kind="bar", title = "Violation codes with their corresponding counts")
counts_chart.set_xlabel("Violation codes")
counts_chart.set_ylabel("Corresponding violation counts")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
#groupby plate type 
plate_gb = tickets_df.groupby("Plate Type")["Violation Code"].nunique()
plate_gb
# unique_code = plate_gb["Violation Code"].unique()
# unique_code
# Out:
# Plate Type
# 999    16
# AMB     1
# APP     4
# AYG     1
# BOB     1
# CHC     3
# CMH     2
# COM    53
# DLR     1
# HIR     1
# IRP    22
# ITP     4
# LMB     1
# MED    15
# MOT     4
# NLM     1
# OML    11
# OMR    12
# OMS    30
# OMT    41
# ORC     2
# ORG    17
# PAS    53
# PHS     1
# PSD     3
# RGL    11
# SCL     5
# SEM     2
# SPO    12
# SRF    24
# SRN     8
# STA     1
# TOW     9
# TRA     2
# TRC    13
# TRL     3
# VAS     8
# Name: Violation Code, dtype: int64

# %%
# unique_code_nuni = plate_gb["Violation Code"].nunique()
# unique_code_nuni

# %%
#By doing this way it is getting over written
unique_code_charts = plate_gb.plot(kind="pie")
plt.show()

# %%
# Plate_type = ["999", "CHC", "COM", "IRP", "MED", "MOT", "OML", "OMR", "OMT", "ORG", "PAS", "PSD", "RGL", "SCL", "SPO", "SRF", "SRN", "STA", "TOW", "TRC", "TRL", "VSA"]
# Violation_code = [7,1,42,11,7,1,4,6,20,28,11,45,2,5,4,6,18,3,1,4,7,2,2]

# %%
# x_axis = np.arange(len(Violation_code))

# %%
# plt.barh(x_axis, Violation_code)
# colour="r", align="center")
