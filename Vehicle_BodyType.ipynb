# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the input data file

# %% [markdown]
# Plate IDs seem to be unique - so all entries/records seem to be unique

# %%
#Read the csv file
df=pd.read_csv("Resources\Parkingtickets_Dec2016.csv")
df
# Out:
#       Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0      GYG8911                 NY        PAS  12/18/2016              24
# 1        8P82H                 NY        OMT  12/21/2016              14
# 2      GML6346                 NY        PAS  12/19/2016              21
# 3      12203MG                 NY        COM   12/1/2016              46
# 4      HEG7444                 NY        PAS   12/1/2016              36
# ...        ...                ...        ...         ...             ...
# 30908  GCV1621                 PA        PAS  12/25/2016               7
# 30909  GVH3100                 NY        PAS   12/5/2016              21
# 30910  GZK6941                 NY        PAS   12/2/2016              36
# 30911  GCL2009                 NY        PAS  12/29/2016               7
# 30912  GDL7195                 NY        PAS  12/14/2016              36
#
#       Vehicle Body Type Vehicle Make Violation Time Violation County  \
# ...

# %% [markdown]
# Dataset Observations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30913 entries, 0 to 30912
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Plate ID               30913 non-null  object
#  1   Registration State     30913 non-null  object
#  2   Plate Type             30913 non-null  object
#  3   Issue Date             30913 non-null  object
#  4   Violation Code         30913 non-null  int64
#  5   Vehicle Body Type      30864 non-null  object
#  6   Vehicle Make           30846 non-null  object
#  7   Violation Time         30913 non-null  object
#  8   Violation County       30838 non-null  object
#  9   From Hours In Effect   13175 non-null  object
#  10  To Hours In Effect     13175 non-null  object
#  11  Vehicle Color          30423 non-null  object
#  12  Vehicle Year           30913 non-null  int64
#  13  Meter Number           4499 non-null   object
# ...

# %%
#This checks for missing value in dataframe
pd.isnull(df).sum()
# Out:
# Plate ID                     0
# Registration State           0
# Plate Type                   0
# Issue Date                   0
# Violation Code               0
# Vehicle Body Type           49
# Vehicle Make                67
# Violation Time               0
# Violation County            75
# From Hours In Effect     17738
# To Hours In Effect       17738
# Vehicle Color              490
# Vehicle Year                 0
# Meter Number             26414
# Violation Post Code      12815
# Violation Description     2743
# dtype: int64

# %% [markdown]
# Data cleaning & sorting

# %%
#Delete column from df
del df['From Hours In Effect']
df.head()

# %%
#Delete column from df
del df['To Hours In Effect']
df.head()
# Out:
#   Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0  GYG8911                 NY        PAS  12/18/2016              24
# 1    8P82H                 NY        OMT  12/21/2016              14
# 2  GML6346                 NY        PAS  12/19/2016              21
# 3  12203MG                 NY        COM   12/1/2016              46
# 4  HEG7444                 NY        PAS   12/1/2016              36
#
#   Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 0              SUBN         JEEP          1204P                Q
# 1              TAXI        NISSA          1015A               NY
# 2               SDN        HONDA          1212P                K
# 3               VAN        FRUEH          1137A               NY
# 4              4DSD          BMW          1027A               BK
#
#   Vehicle Color  Vehicle Year Meter Number Violation Post Code  \
# 0            BK          2015          NaN                15 4
# ...

# %%
#Df with vehicle body type & violation code
vb=df.drop(['Plate ID','Registration State', 'Plate Type', 'Issue Date', 'Vehicle Make','Violation Time','Violation County','Vehicle Color', 'Vehicle Year','Meter Number','Violation Post Code', 'Violation Description'], axis=1)
vb
# Out:
#        Violation Code Vehicle Body Type
# 0                  24              SUBN
# 1                  14              TAXI
# 2                  21               SDN
# 3                  46               VAN
# 4                  36              4DSD
# ...               ...               ...
# 30908               7               SDN
# 30909              21              SUBN
# 30910              36              4DSD
# 30911               7              SUBN
# 30912              36              4DSD
#
# [30913 rows x 2 columns]

# %%
vc=vb.groupby('Vehicle Body Type')
vc=vc.sum()

# %%
a=vc.count()
a.reset_index()
# Out:
#     Vehicle Body Type  Violation Code
# 0                2 DR              20
# 1                  2D              11
# 2                2DSD             705
# 3                  2S               2
# 4                  3D               1
# ..                ...             ...
# 107              WAGO             216
# 108              WDOO               1
# 109                WG               1
# 110              WRAN               1
# 111                ZL               1
#
# [112 rows x 2 columns]

# %%
#plot a bar graph for violation code v body type

# %%
#calculate percentage of violations per body type. consider top 5, if % less than 1 or very low, then combine those values as others
#plot a pie chart for body type.

# %%
#analysis-suggestion from Sai-T test look into that

# %%
#Look for more patterns?

# %%
pie chart

# %%
# #Drop rows with missing values-no need to drop rows with Nan
# df=df.dropna(axis=0, how='any')
# df.head()
# Out:
#    Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 9   GMR2584                 NY        PAS   12/1/2016              37
# 21  35079MD                 NY        COM   12/8/2016              42
# 22  98166MD                 NY        COM   12/8/2016              42
# 24  GBD7091                 NY        PAS   12/7/2016              37
# 26  GVK6209                 NY        PAS  12/10/2016              37
#
#    Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 9               4DSD        HYUND          1110A                K
# 21               VAN        NS/OT          1258P               NY
# 22               VAN        CHEVR          0307P               NY
# 24              SUBN          BMW          0639P               NY
# 26              SUBN        HONDA          1149A                K
#
#    From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 9                 0900A              0700P            GY          2013
# ...

# %%
#Check for missing data after cleanup
pd.isnull(df).sum()
# Out:
# Plate ID                 0
# Registration State       0
# Plate Type               0
# Issue Date               0
# Violation Code           0
# Vehicle Body Type        0
# Vehicle Make             0
# Violation Time           0
# Violation County         0
# From Hours In Effect     0
# To Hours In Effect       0
# Vehicle Color            0
# Vehicle Year             0
# Meter Number             0
# Violation Post Code      0
# Violation Description    0
# dtype: int64

# %%
#Reset index
cleaned_df=df.reset_index(drop=True)
cleaned_df.head()
# Out:
#   Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0  GMR2584                 NY        PAS   12/1/2016              37
# 1  35079MD                 NY        COM   12/8/2016              42
# 2  98166MD                 NY        COM   12/8/2016              42
# 3  GBD7091                 NY        PAS   12/7/2016              37
# 4  GVK6209                 NY        PAS  12/10/2016              37
#
#   Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 0              4DSD        HYUND          1110A                K
# 1               VAN        NS/OT          1258P               NY
# 2               VAN        CHEVR          0307P               NY
# 3              SUBN          BMW          0639P               NY
# 4              SUBN        HONDA          1149A                K
#
#   From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 0                0900A              0700P            GY          2013
# ...

# %%
#Converted file to excel
cleaned_df.to_excel(r"Resources\Parkingtickets_Dec2016C.xlsx", index=False)

# %%
#Reading cleaned file
cleaned_df=pd.read_excel("Resources\Parkingtickets_Dec2016C.xlsx", index=True)
cleaned_df
# Out:
#      Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0     GMR2584                 NY        PAS   12/1/2016              37
# 1     35079MD                 NY        COM   12/8/2016              42
# 2     98166MD                 NY        COM   12/8/2016              42
# 3     GBD7091                 NY        PAS   12/7/2016              37
# 4     GVK6209                 NY        PAS  12/10/2016              37
# ...       ...                ...        ...         ...             ...
# 1742  DSG5982                 NY        PAS  12/16/2016              37
# 1743  HKD1768                 NY        OMS   12/1/2016              37
# 1744  HFY9287                 NY        PAS  12/20/2016              37
# 1745  88188MH                 NY        COM  12/22/2016              37
# 1746  53493ME                 NY        COM   12/3/2016              37
#
#      Vehicle Body Type Vehicle Make Violation Time Violation County  \
# ...

# %%
#Cleaned dataframe observations
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1747 entries, 0 to 1746
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Plate ID               1747 non-null   object
#  1   Registration State     1747 non-null   object
#  2   Plate Type             1747 non-null   object
#  3   Issue Date             1747 non-null   object
#  4   Violation Code         1747 non-null   int64
#  5   Vehicle Body Type      1747 non-null   object
#  6   Vehicle Make           1747 non-null   object
#  7   Violation Time         1747 non-null   object
#  8   Violation County       1747 non-null   object
#  9   From Hours In Effect   1747 non-null   object
#  10  To Hours In Effect     1747 non-null   object
#  11  Vehicle Color          1747 non-null   object
#  12  Vehicle Year           1747 non-null   int64
#  13  Meter Number           1747 non-null   object
# ...

# %%
cleaned_df
# Out:
#      Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0     GMR2584                 NY        PAS   12/1/2016              37
# 1     35079MD                 NY        COM   12/8/2016              42
# 2     98166MD                 NY        COM   12/8/2016              42
# 3     GBD7091                 NY        PAS   12/7/2016              37
# 4     GVK6209                 NY        PAS  12/10/2016              37
# ...       ...                ...        ...         ...             ...
# 1742  DSG5982                 NY        PAS  12/16/2016              37
# 1743  HKD1768                 NY        OMS   12/1/2016              37
# 1744  HFY9287                 NY        PAS  12/20/2016              37
# 1745  88188MH                 NY        COM  12/22/2016              37
# 1746  53493ME                 NY        COM   12/3/2016              37
#
#      Vehicle Body Type Vehicle Make Violation Time Violation County  \
# ...

# %%
vc=cleaned_df.groupby('Violation Code').count()
vc
# Out:
#                 Plate ID  Registration State  Plate Type  Issue Date  \
# Violation Code
# 37                  1636                1636        1636        1636
# 42                   110                 110         110         110
# 43                     1                   1           1           1
#
#                 Vehicle Body Type  Vehicle Make  Violation Time  \
# Violation Code
# 37                           1636          1636            1636
# 42                            110           110             110
# 43                              1             1               1
#
#                 Violation County  From Hours In Effect  To Hours In Effect  \
# Violation Code
# 37                          1636                  1636                1636
# 42                           110                   110                 110
# 43                             1                     1                   1
#
#                 Vehicle Color  Vehicle Year  Meter Number  \
# ...
