# %%
#Gather information about how a vehicles color can correlate with a higher/lower likelihood of getting a violation
#Going by quantity of violations, not by what kind of violation
#We want to see the effect of having certain color cars has to do with getting a violation
#Later, we may delve into what kind of tickets are promiment for each color and see if that is statistically significant

# %%
#Import libraries as needed
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
#Read in CSV File and convert it into a dataframe
inputFile = "Resources/Parkingtickets_Dec2016.csv"
vehicleColor_df = pd.read_csv(inputFile)

vehicleColor_df.head()
# Out:
#   Plate ID Registration State Plate Type  Issue Date  Violation Code  \
# 0  GYG8911                 NY        PAS  12/18/2016              24
# 1    8P82H                 NY        OMT  12/21/2016              14
# 2  GML6346                 NY        PAS  12/19/2016              21
# 3  12203MG                 NY        COM   12/1/2016              46
# 4  HEG7444                 NY        PAS   12/1/2016              36
#
#   Vehicle Body Type Vehicle Make Violation Time Violation County  \
# 0              SUBN         JEEP          1204P                Q
# 1              TAXI        NISSA          1015A               NY
# 2               SDN        HONDA          1212P                K
# 3               VAN        FRUEH          1137A               NY
# 4              4DSD          BMW          1027A               BK
#
#   From Hours In Effect To Hours In Effect Vehicle Color  Vehicle Year  \
# 0                  NaN                NaN            BK          2015
# ...

# %%
#Clean dataframe to only have NY plates and list all others as "Other"

# %%
#Sort Dataframe in ascending order and only show the top five violations occurences (maybe)

# %%
#Plot a Pie Graph with how many violations each color receives

#Calculate statistical data to see if there is any significance with this data

# %%
#Plot a bar graph with how many violations each color receives

#Calculate statistical data to see if there is any significance with this data

# %%
#Calculate statistical data to see if there is any significance with this data
